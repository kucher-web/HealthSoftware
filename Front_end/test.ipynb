# %%
# 导入函数库
import streamlit as st
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import Functions as f
from satellite import Satellite_angle,TMK,TMO,TMZ

# %%
# 读取数据
df = pd.read_csv('data.csv')
df
# Out:
#                       用例ID  卫星编号 厂商类型信息  SCID    遥测代号              遥测名称  \
# 0      T771196799007326976  4112    小卫星  4112  TMZ059          星地时延补偿开关
# 1      T771196799007326976  4112    小卫星  4112  TMZ088  QV2 轴1（副面轴）霍尔2状态
# 2      T771196799007326976  4112    小卫星  4112  TMZ105       QV2工作模式状态查询
# 3      T771196799007326976  4112    小卫星  4112  TMZ104                备用
# 4      T771196799007326976  4112    小卫星  4112  TMZ043      主用业务跳波束图案表状态
# ...                    ...   ...    ...   ...     ...               ...
# 41174  T771196799007326976  4112    小卫星  4112  TMS010        SADA通讯复位计数
# 41175  T771196799007326976  4112    小卫星  4112  TMS006        SADA遥测请求计数
# 41176  T771196799007326976  4112    小卫星  4112  TMS046             PPS计数
# 41177  T771196799007326976  4112    小卫星  4112  TMS045           当前程序运行区
# 41178  T771196799007326976  4112    小卫星  4112  TMS044       程序校验错误bit计数
#
#                 物理值       原始值  实际值                 星上时间                 采集时间  \
# 0                 关         0    0  2025-02-16 02:30:14  2025-02-16 02:31:40
# 1      当前位置未检测到霍尔信号         0    0  2025-02-16 02:30:14  2025-02-16 02:31:40
# 2              跟踪模式        03    3  2025-02-16 02:30:14  2025-02-16 02:31:40
# 3                82       052   82  2025-02-16 02:30:14  2025-02-16 02:31:40
# 4                 空         0    0  2025-02-16 02:30:14  2025-02-16 02:31:40
# ...             ...       ...  ...                  ...                  ...
# 41174             0        00    0  2025-02-16 02:26:46  2025-02-16 02:26:49
# 41175           197        c5  197  2025-02-16 02:26:46  2025-02-16 02:26:49
# 41176           196        c4  196  2025-02-16 02:26:46  2025-02-16 02:26:49
# 41177          主运行区        aa  170  2025-02-16 02:26:46  2025-02-16 02:26:49
# 41178             0  00000000    0  2025-02-16 02:26:46  2025-02-16 02:26:49
#
#                设备名称                  设备SN序列号   基站ID
# 0      新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# 1      新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# 2      新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# 3      新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# 4      新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# ...             ...                      ...    ...
# 41174  新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# 41175  新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# 41176  新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# 41177  新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
# 41178  新疆信关站_基站_196  SG04-DJJZ-AR-2024040015  69892
#
# [41179 rows x 14 columns]

# %%
# 删除只有一个非重复值的列
columns = [col for col in df.columns if df[col].nunique() > 1]
df = df[columns]
df
# Out:
#          遥测代号              遥测名称           物理值       原始值  实际值  \
# 0      TMZ059          星地时延补偿开关             关         0    0
# 1      TMZ088  QV2 轴1（副面轴）霍尔2状态  当前位置未检测到霍尔信号         0    0
# 2      TMZ105       QV2工作模式状态查询          跟踪模式        03    3
# 3      TMZ104                备用            82       052   82
# 4      TMZ043      主用业务跳波束图案表状态             空         0    0
# ...       ...               ...           ...       ...  ...
# 41174  TMS010        SADA通讯复位计数             0        00    0
# 41175  TMS006        SADA遥测请求计数           197        c5  197
# 41176  TMS046             PPS计数           196        c4  196
# 41177  TMS045           当前程序运行区          主运行区        aa  170
# 41178  TMS044       程序校验错误bit计数             0  00000000    0
#
#                       星上时间                 采集时间
# 0      2025-02-16 02:30:14  2025-02-16 02:31:40
# 1      2025-02-16 02:30:14  2025-02-16 02:31:40
# 2      2025-02-16 02:30:14  2025-02-16 02:31:40
# 3      2025-02-16 02:30:14  2025-02-16 02:31:40
# 4      2025-02-16 02:30:14  2025-02-16 02:31:40
# ...                    ...                  ...
# 41174  2025-02-16 02:26:46  2025-02-16 02:26:49
# 41175  2025-02-16 02:26:46  2025-02-16 02:26:49
# 41176  2025-02-16 02:26:46  2025-02-16 02:26:49
# 41177  2025-02-16 02:26:46  2025-02-16 02:26:49
# 41178  2025-02-16 02:26:46  2025-02-16 02:26:49
#
# [41179 rows x 7 columns]

# %%
# 把遥测代号和遥测名称合并，用于后续的图表展示
df['遥测'] = df['遥测代号'] + '_' + df['遥测名称']
df = df.drop(['遥测代号', '遥测名称','采集时间'], axis=1)
df
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_1612\1622899594.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['遥测'] = df['遥测代号'] + '_' + df['遥测名称']
#                 物理值       原始值  实际值                 星上时间  \
# 0                 关         0    0  2025-02-16 02:30:14
# 1      当前位置未检测到霍尔信号         0    0  2025-02-16 02:30:14
# 2              跟踪模式        03    3  2025-02-16 02:30:14
# 3                82       052   82  2025-02-16 02:30:14
# 4                 空         0    0  2025-02-16 02:30:14
# ...             ...       ...  ...                  ...
# 41174             0        00    0  2025-02-16 02:26:46
# 41175           197        c5  197  2025-02-16 02:26:46
# 41176           196        c4  196  2025-02-16 02:26:46
# 41177          主运行区        aa  170  2025-02-16 02:26:46
# 41178             0  00000000    0  2025-02-16 02:26:46
#
#                             遥测
# 0              TMZ059_星地时延补偿开关
# 1      TMZ088_QV2 轴1（副面轴）霍尔2状态
# 2           TMZ105_QV2工作模式状态查询
# 3                    TMZ104_备用
# 4          TMZ043_主用业务跳波束图案表状态
# ...                        ...
# 41174        TMS010_SADA通讯复位计数
# 41175        TMS006_SADA遥测请求计数
# 41176             TMS046_PPS计数
# 41177           TMS045_当前程序运行区
# 41178       TMS044_程序校验错误bit计数
#
# [41179 rows x 5 columns]

# %%
# 只需要一部分数据，输入需要的遥测名称
columns = ['TMK505', 'TMK506', 'TMK507', 'TMK508', 'TMK509', 'TMK510', 'TMZ148', 'TMZ150', 'TMZ151','TMZ152','TMZ153', 'TMO108', 'TMO109', 'TMO110', 'TMO111', 'TMO112', 'TMO113', 'TMO114', 'TMO115', 'TMZ067', 'TMZ068']
# 查找遥测列中包含columns中的元素的行
filtered_df = df[df['遥测'].notna()]  # First, filter out rows with NaN values in '遥测' column
filtered_df = filtered_df[filtered_df['遥测'].str.contains('|'.join(columns))]
filtered_df
# Out:
#                物理值       原始值          实际值                 星上时间  \
# 161          -0.12      fff4        -0.12  2025-02-16 02:30:14
# 165            0.1      000a          0.1  2025-02-16 02:30:14
# 2397   -0.00044103  b70123fe  -0.00044103  2025-02-16 02:30:06
# 2399   -0.00078376  b7658000  -0.00078376  2025-02-16 02:30:06
# 2400   -0.00008735  b5cc9ffd  -0.00008735  2025-02-16 02:30:06
# ...            ...       ...          ...                  ...
# 40687  -0.00153573  b7e0d800  -0.00153573  2025-02-16 02:26:46
# 40689   -0.0007613  b75eebae   -0.0007613  2025-02-16 02:26:46
# 40691  -0.00003576  b5278eae  -0.00003576  2025-02-16 02:26:46
# 41027        -0.12      fff4        -0.12  2025-02-16 02:26:46
# 41028          0.1      000a          0.1  2025-02-16 02:26:46
#
#                             遥测
# 161    TMZ067_QV1轴1（副面轴）转台绝对位置
# 165    TMZ068_QV1轴2（主面轴）转台绝对位置
# 2397       TMK505_轨道系姿态角EulerX
# 2399       TMK506_轨道系姿态角EulerY
# 2400       TMK507_轨道系姿态角EulerZ
# ...                        ...
# 40687      TMK507_轨道系姿态角EulerZ
# 40689        TMK508_轨道系角速度wbox
# 40691        TMK510_轨道系角速度wboz
# 41027  TMZ067_QV1轴1（副面轴）转台绝对位置
# 41028  TMZ068_QV1轴2（主面轴）转台绝对位置
#
# [249 rows x 5 columns]

# %%
# 便利遥测数据，把数据填充到类中
def fill_df(filtered_df):
    satellite_angles = []

    # 先把数据表格按照星上时间排序
    filtered_df = filtered_df.sort_values(by='星上时间')
    filtered_df = filtered_df.reset_index(drop=True)

    for index, row in filtered_df.iterrows():#+
        # 以星上时间为索引，当星上时间变化时，把上一个卫星姿态数据加入到列表中
        if satellite_angle.time != row['星上时间'] and satellite_angle.time != None:
            satellite_angles.append(satellite_angle)
            satellite_angle = Satellite_angle()  
        satellite_angle.time = row['星上时间']#+
        if "TMK505" in row['遥测']:
            satellite_angle.tmk.TMK505 = row['实际值']
        elif "TMK506" in row['遥测']:
            satellite_angle.tmk.TMK506 = row['实际值']
        elif "TMK507" in row['遥测']:
            satellite_angle.tmk.TMK507 = row['实际值']
        elif "TMK508" in row['遥测']:
            satellite_angle.tmk.TMK508 = row['实际值']
        elif "TMK509" in row['遥测']:
            satellite_angle.tmk.TMK509 = row['实际值']
        elif "TMK510" in row['遥测']:
            satellite_angle.tmk.TMK510 = row['实际值']
        elif "TMZ148" in row['遥测']:
            satellite_angle.tmz.TMZ148 = row['实际值']
        elif "TMZ150" in row['遥测']:
            satellite_angle.tmz.TMZ150 = row['实际值']
        elif "TMZ151" in row['遥测']:
            satellite_angle.tmz.TMZ151 = row['实际值']
        elif "TMZ152" in row['遥测']:
            satellite_angle.tmz.TMZ152 = row['实际值']
        elif "TMZ153" in row['遥测']:
            satellite_angle.tmz.TMZ153 = row['实际值']
        elif "TMZ067" in row['遥测']:
            satellite_angle.tmz.TMZ067 = row['实际值']
        elif "TMZ068" in row['遥测']:
            satellite_angle.tmz.TMZ068 = row['实际值']
        elif "TMO108" in row['遥测']:
            satellite_angle.tmo.TMO108 = row['实际值']
        elif "TMO109" in row['遥测']:
            satellite_angle.tmo.TMO109 = row['实际值']
        elif "TMO110" in row['遥测']:
            satellite_angle.tmo.TMO110 = row['实际值']
        elif "TMO111" in row['遥测']:
            satellite_angle.tmo.TMO111 = row['实际值']
        elif "TMO112" in row['遥测']:
            satellite_angle.tmo.TMO112 = row['实际值']
        elif "TMO113" in row['遥测']:
            satellite_angle.tmo.TMO113 = row['实际值']
        elif "TMO114" in row['遥测']:
            satellite_angle.tmo.TMO114 = row['实际值']
        elif "TMO115" in row['遥测']:
            satellite_angle.tmo.TMO115 = row['实际值']

# %%
# 新建一个表格，序列为星上时间，列为遥测名称，值为实际值
df_pivot = filtered_df.pivot(index="星上时间", columns='遥测', values='实际值')
# 重置索引
df_pivot = df_pivot.reset_index()
df_pivot
# Out:
# 遥测                 星上时间 TMK505_轨道系姿态角EulerX TMK506_轨道系姿态角EulerY  \
# 0   2025-02-16 02:26:46         -0.00300229          0.05559433
# 1   2025-02-16 02:26:54         -0.00200215           0.0745225
# 2   2025-02-16 02:27:02         -0.00332422          0.08519297
# 3   2025-02-16 02:27:10         -0.00405841          0.08472682
# 4   2025-02-16 02:27:18         -0.00387058          0.05776461
# 5   2025-02-16 02:27:26         -0.00001905          0.01303029
# 6   2025-02-16 02:27:27                 NaN                 NaN
# 7   2025-02-16 02:27:34         -0.00118509         -0.02370587
# 8   2025-02-16 02:27:42         -0.00099908         -0.04981086
# 9   2025-02-16 02:27:50         -0.00266078          -0.0609065
# 10  2025-02-16 02:27:58         -0.00036894          -0.0624211
# 11  2025-02-16 02:28:06         -0.00401791         -0.05356918
# 12  2025-02-16 02:28:14         -0.00134341         -0.04315655
# 13  2025-02-16 02:28:22           -0.007236          -0.0321719
# 14  2025-02-16 02:28:30          0.00531773         -0.02440427
# 15  2025-02-16 02:28:31                 NaN                 NaN
# 16  2025-02-16 02:28:38          0.00310982         -0.01725818
# 17  2025-02-16 02:28:46         -0.00576959         -0.01194259
# 18  2025-02-16 02:28:54           0.0024871         -0.00958276
# 19  2025-02-16 02:29:02          0.00194052          -0.0054078
# 20  2025-02-16 02:29:10          0.00829067         -0.00723488
# 21  2025-02-16 02:29:18         -0.00157617         -0.00522851
# 22  2025-02-16 02:29:26           0.0004962         -0.00295406
# 23  2025-02-16 02:29:34          0.00385986          -0.0028738
# 24  2025-02-16 02:29:35                 NaN                 NaN
# 25  2025-02-16 02:29:42            0.012142         -0.00247253
# 26  2025-02-16 02:29:50         -0.00232258         -0.00535828
# 27  2025-02-16 02:29:58         -0.00067277         -0.00353633
# 28  2025-02-16 02:30:06         -0.00044103         -0.00078376
# 29  2025-02-16 02:30:14                 NaN                 NaN
#
# 遥测 TMK507_轨道系姿态角EulerZ TMK508_轨道系角速度wbox TMK509_轨道系角速度wboy TMK510_轨道系角速度wboz  \
# 0          -0.00153573        -0.0007613        0.00388193       -0.00003576
# 1          -0.00003554        0.00137725       -0.00173591        0.00040828
# 2          -0.00036867       -0.00004224        0.00215537        0.00132299
# 3          -0.00153775        0.00108824       -0.00601438         0.0005569
# 4          -0.00224382        0.00182906       -0.00248796        0.00070134
# 5          -0.00121727         0.0085435       -0.00873793       -0.00110629
# 6                  NaN               NaN               NaN               NaN
# 7          -0.00228454       -0.00097968       -0.00199205        0.00104375
# 8          -0.00268469        0.00153217        -0.0043339       -0.00076688
# 9          -0.00181646        0.00224212        0.00019684       -0.00052027
# 10          -0.0014774        0.00375199       -0.00285206       -0.00272872
# 11         -0.00122511       -0.00476323        0.00184562        0.00032886
# 12         -0.00171971       -0.00140316       -0.00325779        0.00000102
# 13          0.00032022        -0.0073122        0.00373323        0.00081243
# 14          0.00041184        0.01968795        -0.0019995        -0.0003574
# 15                 NaN               NaN               NaN               NaN
# 16         -0.00035949        0.00772969        0.00181704       -0.00133759
# 17         -0.00034802       -0.03399814        0.00418367       -0.00044497
# 18         -0.00049599        0.00728321        0.00216987       -0.00004189
# 19          0.00003026        0.00586745        0.00094199        0.00085525
# 20           0.0021808         0.0296436       -0.00163542        0.00091815
# 21          0.00169917       -0.01662139       -0.00351513       -0.00188437
# 22         -0.00096749       -0.00063288       -0.00207196       -0.00106248
# 23          0.00147665        0.00125399        0.00079485        0.00167394
# 24                 NaN               NaN               NaN               NaN
# 25          0.00313724        0.03127565       -0.00126796         0.0044223
# 26         -0.00004002       -0.01750141       -0.00216478       -0.00304959
# 27          0.00133781       -0.00741924       -0.00308707       -0.00242441
# 28         -0.00008735       -0.00543901        0.00175443        0.00061361
# 29                 NaN               NaN               NaN               NaN
#
# 遥测 TMO108_WGS84短时外推时间秒 TMO109_WGS84短时外推时间微秒 TMO110_WGS84短时外推位置X  ...  \
# 0                  NaN                  NaN                 NaN  ...
# 1                  NaN                  NaN                 NaN  ...
# 2                  NaN                  NaN                 NaN  ...
# 3                  NaN                  NaN                 NaN  ...
# 4                  NaN                  NaN                 NaN  ...
# 5                  NaN                  NaN                 NaN  ...
# 6        1739644047000                  750        316969.03125  ...
# 7                  NaN                  NaN                 NaN  ...
# 8                  NaN                  NaN                 NaN  ...
# 9                  NaN                  NaN                 NaN  ...
# 10                 NaN                  NaN                 NaN  ...
# 11                 NaN                  NaN                 NaN  ...
# 12                 NaN                  NaN                 NaN  ...
# 13                 NaN                  NaN                 NaN  ...
# 14                 NaN                  NaN                 NaN  ...
# 15       1739644111000                  750         351863.5625  ...
# 16                 NaN                  NaN                 NaN  ...
# 17                 NaN                  NaN                 NaN  ...
# 18                 NaN                  NaN                 NaN  ...
# 19                 NaN                  NaN                 NaN  ...
# 20                 NaN                  NaN                 NaN  ...
# 21                 NaN                  NaN                 NaN  ...
# 22                 NaN                  NaN                 NaN  ...
# 23                 NaN                  NaN                 NaN  ...
# 24       1739644175000                  750         388726.3125  ...
# 25                 NaN                  NaN                 NaN  ...
# 26                 NaN                  NaN                 NaN  ...
# 27                 NaN                  NaN                 NaN  ...
# 28                 NaN                  NaN                 NaN  ...
# 29                 NaN                  NaN                 NaN  ...
#
# 遥测 TMO113_WGS84短时外推速度X TMO114_WGS84短时外推速度Y TMO115_WGS84短时外推速度Z  \
# 0                  NaN                 NaN                 NaN
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                  NaN                 NaN                 NaN
# 4                  NaN                 NaN                 NaN
# 5                  NaN                 NaN                 NaN
# 6         528.22119141       5888.61865234      -4295.67041016
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                  NaN                 NaN                 NaN
# 10                 NaN                 NaN                 NaN
# 11                 NaN                 NaN                 NaN
# 12                 NaN                 NaN                 NaN
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15        561.42919922       5604.17919922      -4658.04296875
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 NaN                 NaN                 NaN
# 19                 NaN                 NaN                 NaN
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22                 NaN                 NaN                 NaN
# 23                 NaN                 NaN                 NaN
# 24        589.68084717       5297.52734375      -5002.03027344
# 25                 NaN                 NaN                 NaN
# 26                 NaN                 NaN                 NaN
# 27                 NaN                 NaN                 NaN
# 28                 NaN                 NaN                 NaN
# 29                 NaN                 NaN                 NaN
#
# 遥测 TMZ067_QV1轴1（副面轴）转台绝对位置 TMZ068_QV1轴2（主面轴）转台绝对位置 TMZ148_馈电指向时间_秒  \
# 0                    -0.12                     0.1             NaN
# 1                    -0.12                     0.1             NaN
# 2                    -0.12                     0.1             NaN
# 3                    -0.12                     0.1             NaN
# 4                    -0.12                     0.1             NaN
# 5                    -0.12                     0.1       161807246
# 6                      NaN                     NaN             NaN
# 7                    -0.12                     0.1             NaN
# 8                    -0.12                     0.1             NaN
# 9                    -0.12                     0.1             NaN
# 10                   -0.12                     0.1             NaN
# 11                   -0.12                     0.1             NaN
# 12                   -0.12                     0.1             NaN
# 13                   -0.12                     0.1             NaN
# 14                   -0.12                     0.1       161807310
# 15                     NaN                     NaN             NaN
# 16                   -0.12                     0.1             NaN
# 17                   -0.12                     0.1             NaN
# 18                   -0.12                     0.1             NaN
# 19                   -0.12                     0.1             NaN
# 20                   -0.12                     0.1             NaN
# 21                   -0.12                     0.1             NaN
# 22                   -0.12                     0.1             NaN
# 23                   -0.12                     0.1       161807373
# 24                     NaN                     NaN             NaN
# 25                   -0.12                     0.1             NaN
# 26                   -0.12                     0.1             NaN
# 27                   -0.12                     0.1             NaN
# 28                   -0.12                     0.1             NaN
# 29                   -0.12                     0.1             NaN
#
# 遥测 TMZ150_馈电1俯仰角 TMZ151_馈电1方位角 TMZ152_馈电2信关站 TMZ153_馈电2俯仰角
# 0            NaN           NaN           NaN           NaN
# 1            NaN           NaN           NaN           NaN
# 2            NaN           NaN           NaN           NaN
# 3            NaN           NaN           NaN           NaN
# 4            NaN           NaN           NaN           NaN
# 5              0             0            17   48.40000153
# 6            NaN           NaN           NaN           NaN
# 7            NaN           NaN           NaN           NaN
# 8            NaN           NaN           NaN           NaN
# 9            NaN           NaN           NaN           NaN
# 10           NaN           NaN           NaN           NaN
# 11           NaN           NaN           NaN           NaN
# 12           NaN           NaN           NaN           NaN
# 13           NaN           NaN           NaN           NaN
# 14             0             0            17         40.75
# 15           NaN           NaN           NaN           NaN
# 16           NaN           NaN           NaN           NaN
# 17           NaN           NaN           NaN           NaN
# 18           NaN           NaN           NaN           NaN
# 19           NaN           NaN           NaN           NaN
# 20           NaN           NaN           NaN           NaN
# 21           NaN           NaN           NaN           NaN
# 22           NaN           NaN           NaN           NaN
# 23             0             0            17         28.75
# 24           NaN           NaN           NaN           NaN
# 25           NaN           NaN           NaN           NaN
# 26           NaN           NaN           NaN           NaN
# 27           NaN           NaN           NaN           NaN
# 28           NaN           NaN           NaN           NaN
# 29           NaN           NaN           NaN           NaN
#
# [30 rows x 22 columns]
